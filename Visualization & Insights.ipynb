# %%
import pandas as pd

d1 = pd.read_csv(r"Zipcode-Bigger.csv")
d2 = pd.read_csv(r"Zipcode-Metrics.csv")

# %%
d2.sort_values(by=['Payback_Period','ROI'],ascending=[True,False],inplace=True)
d2
# Out:
#     zipcode  Current Selling Price      Rate  AnnualRentofProperty  \
# 15    10312                 355000    3310.0          58856.250000
# 11    10304                 328300    2510.0          26553.750000
# 13    10306                 352900    2520.0          25458.750000
# 21    11434                 382300    -800.0          27222.916667
# 20    11234                 476900    6630.0          29382.500000
# 12    10305                 425100    7720.0          30447.083333
# 14    10308                 409500    5900.0          17793.750000
# 17    11215                1070800   56770.0          49610.877660
# 9     10036                1712900   53290.0          99650.069444
# 19    11231                1202900   64240.0          55526.250000
# 18    11217                1302300   74870.0          58827.601744
# 7     10025                1431000   54760.0          78292.500000
# 5     10022                2031600   61280.0         100545.493421
# ...

# %%
#plot current selling price zipcodes
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
d2.sort_values(by='Current Selling Price',ascending=True,inplace=True)
sns.barplot(x="zipcode", y="Current Selling Price", data=d2)
plt.show()

# %% [markdown]
# # Annual Rent is the price of an AirBnB property assuming 75% occupancy. We check here how annual rent varies with zipcode. Zips - 10011,10022,10036 have the highest mean annual rents

# %%
#plot annual rent by zipcodes
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
d2.sort_values(by='AnnualRentofProperty',ascending=True,inplace=True)
sns.barplot(x="zipcode", y="AnnualRentofProperty", data=d2)
plt.show()

# %% [markdown]
# # Payback period is the number of years required to earn back the initial cost of investment from annual rental income. We check here how payback period varies with zipcode. Zip 10013 has the highest payback period while zip 11434 has the lowest payback period.

# %%
#plot payback period by zipcodes
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
d2.sort_values(by='Payback_Period',ascending=True,inplace=True)
sns.barplot(x="zipcode", y="Payback_Period", data=d2)
plt.show()

# %%
#check relationship been payback period and annual rent
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
sns.scatterplot(data=d2, y="Payback_Period", x="AnnualRentofProperty")

plt.show()

# %% [markdown]
# # We see an increasing trend of payback period with increasing values of annual rent.

# %%
#plot ROI by zipcodes
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.barplot(x="zipcode", y="ROI", data=d2)
plt.show()

# %% [markdown]
# # ROI is return on investment in 10 years assuming rent appreciates at a constant rate without including the equity value of the property.
#
# It is calculated as follows:
#
# (Annual_Rent(1+Rate/100) ^10)/Current Price of the property
#
# #roi_incc takes into account the return on investment through rental as well as equity appreciation i.e. the increase in the price of the house is also taken into account.It is is calculated as:
#
# A= (Annual Rent(1+Rate/100) ^10)/Price of the property {Rent amount in 10 years}
#
# B= (Price of Property(1+Rate/100) ^10)-Price Of property {Increase in cost of property in 10 Years}
#
# Roi_incc= (A+B)/Price of Property

# %%
#plot ROI_incc by zipcodes
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.barplot(x="zipcode", y="ROI_incc", data=d2)
plt.show()

# %% [markdown]
# # Zip 10013 which has the highest current annual price is also seen to have the highest ROI

# %%
#check relationship between current selling price and annual rent
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
d2.sort_values(by='AnnualRentofProperty',ascending=True,inplace=True)
sns.scatterplot(data=d2, x="Current Selling Price", y="AnnualRentofProperty")

plt.show()
